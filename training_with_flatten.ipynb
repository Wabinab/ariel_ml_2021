# %%
storage_name = "./prediction_06062021.txt"

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tempfile

import numpy as np
import pandas as pd
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import metrics
from tensorflow.keras.layers import Dense

# %%
class ArielChallengeMetricNumerator(metrics.Metric):
    def __init__(self, name="ariel_challenge_metric_num", **kwargs):
        super(ArielChallengeMetricNumerator, self).__init__(name=name, **kwargs)
        self.weight = self.add_weight(name="ctp", initializer="zeros")
    #y_true=y, y_pred=pred

    def update_state(self, y_true, y_pred, sample_weight=None):  # score()
        """
        Return the unweighted score related to the challenge. 
        Taken from https://github.com/ucl-exoplanets/ML-challenge-baseline/blob/main/utils.py

        :param y_true: (float) The true label output. 
        :param y_pred: (float) The predicted output. 
        """

        # y_pred = tf.reshape(tf.argmax(y_pred, axis=1), shape=(-1, 1))
        # values = tf.cast(y_true, "int32") == tf.cast(y_pred, "int32")
        # values = tf.cast(values, "float32")

        y_true = tf.cast(y_true, "float32")
        y_pred = tf.cast(y_pred, "float32")

        if sample_weight is not None:
            sample_weight = tf.cast(sample_weight, "float32")
        else:
            sample_weight = tf.ones_like(y_true, dtype="float32")
        
        # new_weight = 1e4 - (tf.reduce_sum(2 * (sample_weight * y_true * tf.math.abs(y_pred - y_true)), axis=None) / (tf.reduce_sum(sample_weight, axis=None)) * 1e6)
        new_weight = tf.reduce_mean(sample_weight * y_true * tf.math.abs(y_pred - y_true))
#         new_weight = tf.cast(new_weight, "float32")
        
        self.weight.assign_add(new_weight)

    def result(self):  # __call__
        return self.weight

    def reset_state(self):
        # The state of the metric will be reset at the start of each epoch.
        self.weight.assign(0.0)

# %%
batch_size = 157  # 1256 is divisible by 157. 
test_batch_size = 77  # 539 is divisible by 77.

# %%
required_test_df = pd.DataFrame()

for table_number in range(55):
    df = pd.read_csv(f"./csv_files/flatten_train_{table_number}.csv", header=None)

    target = df.pop(30000)  # final column is the target/label. 

    train_mean = df.mean()

    mod = abs(df).max()
    # mod_target = abs(target).max()
    
    df -= train_mean
    df /= mod
    # target /= mod_target

    dataset = tf.data.Dataset.from_tensor_slices((df.values, target.values))

    train_dataset = dataset.cache().shuffle(len(df)).batch(batch_size)
    train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)

    tf.keras.backend.clear_session()
    try:
        del model
    except NameError:
        pass

    model = tf.keras.Sequential(
    [
        #306 (incluing extra params for now)
        Dense(4, input_shape=(len(df.columns),), activation=tf.nn.relu),   
        Dense(1024, activation=tf.nn.relu),
        Dense(256, activation=tf.nn.relu),
        Dense(1, activation=tf.nn.sigmoid)
        ])

    model.compile(
        optimizer="adam", 
        loss = 'mean_squared_error', 
        metrics=[ArielChallengeMetricNumerator()]
    )
    
    # callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3, min_delta=0.0002, mode="auto", baseline=None, restore_best_weights=True)

    model.fit(train_dataset, epochs=40, batch_size=batch_size, verbose=2)

    df_test = pd.read_csv(f"./csv_files_test/flatten_test_{table_number}.csv", header=None)

    df_test -= train_mean
    df_test /= mod

    what_is_this = model.predict(df_test, batch_size=test_batch_size)

    required_test_df = pd.concat([required_test_df, pd.DataFrame(what_is_this)], axis=1)
    required_test_df.to_csv(storage_name, header=False, index=False, sep="\t")
    
    print(f"\nTable {table_number} completed.\n")
    
    del df, df_test, target, what_is_this
# Out:
# Epoch 1/40
# 8/8 - 1s - loss: 0.1622 - ariel_challenge_metric_num: 0.1467
# Epoch 2/40
# 8/8 - 0s - loss: 0.0324 - ariel_challenge_metric_num: 0.0601
# Epoch 3/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0266
# Epoch 4/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0303
# Epoch 5/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0313
# Epoch 6/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0316
# Epoch 7/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0316
# Epoch 8/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0316
# Epoch 9/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0316
# Epoch 10/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0315
# Epoch 11/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0314
# Epoch 12/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0312
# Epoch 13/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0311
# Epoch 14/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0309
# Epoch 15/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0307
# Epoch 16/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0304
# Epoch 17/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0300
# Epoch 18/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0295
# Epoch 19/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0289
# Epoch 20/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0280
# Epoch 21/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0271
# Epoch 22/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0261
# Epoch 23/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0246
# Epoch 24/40
# 8/8 - 0s - loss: 0.0023 - ariel_challenge_metric_num: 0.0224
# Epoch 25/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0189
# Epoch 26/40
# 8/8 - 0s - loss: 9.5122e-04 - ariel_challenge_metric_num: 0.0127
# Epoch 27/40
# 8/8 - 0s - loss: 4.0863e-04 - ariel_challenge_metric_num: 0.0082
# Epoch 28/40
# 8/8 - 0s - loss: 4.1507e-04 - ariel_challenge_metric_num: 0.0084
# Epoch 29/40
# 8/8 - 0s - loss: 3.6803e-04 - ariel_challenge_metric_num: 0.0080
# Epoch 30/40
# 8/8 - 0s - loss: 3.5234e-04 - ariel_challenge_metric_num: 0.0078
# Epoch 31/40
# 8/8 - 0s - loss: 3.9013e-04 - ariel_challenge_metric_num: 0.0081
# Epoch 32/40
# 8/8 - 0s - loss: 3.2337e-04 - ariel_challenge_metric_num: 0.0074
# Epoch 33/40
# 8/8 - 0s - loss: 2.5214e-04 - ariel_challenge_metric_num: 0.0064
# Epoch 34/40
# 8/8 - 0s - loss: 2.5139e-04 - ariel_challenge_metric_num: 0.0066
# Epoch 35/40
# 8/8 - 0s - loss: 2.0241e-04 - ariel_challenge_metric_num: 0.0055
# Epoch 36/40
# 8/8 - 0s - loss: 1.6840e-04 - ariel_challenge_metric_num: 0.0047
# Epoch 37/40
# 8/8 - 0s - loss: 1.5702e-04 - ariel_challenge_metric_num: 0.0045
# Epoch 38/40
# 8/8 - 0s - loss: 1.3879e-04 - ariel_challenge_metric_num: 0.0041
# Epoch 39/40
# 8/8 - 0s - loss: 1.2854e-04 - ariel_challenge_metric_num: 0.0038
# Epoch 40/40
# 8/8 - 0s - loss: 1.1841e-04 - ariel_challenge_metric_num: 0.0036
#
# Table 0 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1760 - ariel_challenge_metric_num: 0.1522
# Epoch 2/40
# 8/8 - 0s - loss: 0.0807 - ariel_challenge_metric_num: 0.0901
# Epoch 3/40
# 8/8 - 0s - loss: 0.0129 - ariel_challenge_metric_num: 0.0413
# Epoch 4/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0265
# Epoch 5/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0286
# Epoch 6/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0298
# Epoch 7/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0301
# Epoch 8/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0301
# Epoch 9/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0300
# Epoch 10/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0297
# Epoch 11/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0293
# Epoch 12/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0288
# Epoch 13/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0282
# Epoch 14/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0274
# Epoch 15/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0266
# Epoch 16/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0260
# Epoch 17/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0257
# Epoch 18/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0257
# Epoch 19/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0257
# Epoch 20/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0256
# Epoch 21/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0256
# Epoch 22/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0255
# Epoch 23/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0254
# Epoch 24/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0252
# Epoch 25/40
# 8/8 - 0s - loss: 0.0028 - ariel_challenge_metric_num: 0.0250
# Epoch 26/40
# 8/8 - 0s - loss: 0.0028 - ariel_challenge_metric_num: 0.0245
# Epoch 27/40
# 8/8 - 0s - loss: 0.0026 - ariel_challenge_metric_num: 0.0233
# Epoch 28/40
# 8/8 - 0s - loss: 0.0022 - ariel_challenge_metric_num: 0.0186
# Epoch 29/40
# 8/8 - 0s - loss: 0.0022 - ariel_challenge_metric_num: 0.0218
# Epoch 30/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0250
# Epoch 31/40
# 8/8 - 0s - loss: 0.0026 - ariel_challenge_metric_num: 0.0241
# Epoch 32/40
# 8/8 - 0s - loss: 0.0023 - ariel_challenge_metric_num: 0.0218
# Epoch 33/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0181
# Epoch 34/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0139
# Epoch 35/40
# 8/8 - 0s - loss: 7.2106e-04 - ariel_challenge_metric_num: 0.0109
# Epoch 36/40
# 8/8 - 0s - loss: 8.2957e-04 - ariel_challenge_metric_num: 0.0124
# Epoch 37/40
# 8/8 - 0s - loss: 4.0735e-04 - ariel_challenge_metric_num: 0.0080
# Epoch 38/40
# 8/8 - 0s - loss: 2.9292e-04 - ariel_challenge_metric_num: 0.0068
# Epoch 39/40
# 8/8 - 0s - loss: 2.5070e-04 - ariel_challenge_metric_num: 0.0063
# Epoch 40/40
# 8/8 - 0s - loss: 1.7472e-04 - ariel_challenge_metric_num: 0.0050
#
# Table 1 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1684 - ariel_challenge_metric_num: 0.1547
# Epoch 2/40
# 8/8 - 0s - loss: 0.0384 - ariel_challenge_metric_num: 0.0685
# Epoch 3/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0271
# Epoch 4/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0293
# Epoch 5/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0307
# Epoch 6/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0311
# Epoch 7/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0312
# Epoch 8/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0311
# Epoch 9/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0309
# Epoch 10/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0307
# Epoch 11/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0304
# Epoch 12/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0300
# Epoch 13/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0294
# Epoch 14/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0287
# Epoch 15/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0280
# Epoch 16/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0271
# Epoch 17/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0260
# Epoch 18/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0247
# Epoch 19/40
# 8/8 - 0s - loss: 0.0025 - ariel_challenge_metric_num: 0.0232
# Epoch 20/40
# 8/8 - 0s - loss: 0.0021 - ariel_challenge_metric_num: 0.0209
# Epoch 21/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0180
# Epoch 22/40
# 8/8 - 0s - loss: 0.0013 - ariel_challenge_metric_num: 0.0152
# Epoch 23/40
# 8/8 - 0s - loss: 0.0010 - ariel_challenge_metric_num: 0.0132
# Epoch 24/40
# 8/8 - 0s - loss: 8.0109e-04 - ariel_challenge_metric_num: 0.0118
# Epoch 25/40
# 8/8 - 0s - loss: 5.6595e-04 - ariel_challenge_metric_num: 0.0098
# Epoch 26/40
# 8/8 - 0s - loss: 4.9872e-04 - ariel_challenge_metric_num: 0.0096
# Epoch 27/40
# 8/8 - 0s - loss: 4.8046e-04 - ariel_challenge_metric_num: 0.0095
# Epoch 28/40
# 8/8 - 0s - loss: 4.3743e-04 - ariel_challenge_metric_num: 0.0088
# Epoch 29/40
# 8/8 - 0s - loss: 4.1903e-04 - ariel_challenge_metric_num: 0.0086
# Epoch 30/40
# 8/8 - 0s - loss: 3.7517e-04 - ariel_challenge_metric_num: 0.0080
# Epoch 31/40
# 8/8 - 0s - loss: 3.4490e-04 - ariel_challenge_metric_num: 0.0076
# Epoch 32/40
# 8/8 - 0s - loss: 3.2093e-04 - ariel_challenge_metric_num: 0.0071
# Epoch 33/40
# 8/8 - 0s - loss: 3.1192e-04 - ariel_challenge_metric_num: 0.0071
# Epoch 34/40
# 8/8 - 0s - loss: 3.0178e-04 - ariel_challenge_metric_num: 0.0068
# Epoch 35/40
# 8/8 - 0s - loss: 2.9317e-04 - ariel_challenge_metric_num: 0.0068
# Epoch 36/40
# 8/8 - 0s - loss: 2.8278e-04 - ariel_challenge_metric_num: 0.0066
# Epoch 37/40
# 8/8 - 0s - loss: 2.7961e-04 - ariel_challenge_metric_num: 0.0067
# Epoch 38/40
# 8/8 - 0s - loss: 2.6318e-04 - ariel_challenge_metric_num: 0.0064
# Epoch 39/40
# 8/8 - 0s - loss: 2.5050e-04 - ariel_challenge_metric_num: 0.0061
# Epoch 40/40
# 8/8 - 0s - loss: 2.3780e-04 - ariel_challenge_metric_num: 0.0061
#
# Table 2 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1623 - ariel_challenge_metric_num: 0.1520
# Epoch 2/40
# 8/8 - 0s - loss: 0.0362 - ariel_challenge_metric_num: 0.0655
# Epoch 3/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0274
# Epoch 4/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0315
# Epoch 5/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0327
# Epoch 6/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0331
# Epoch 7/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0331
# Epoch 8/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0331
# Epoch 9/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0330
# Epoch 10/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0329
# Epoch 11/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0327
# Epoch 12/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0324
# Epoch 13/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0321
# Epoch 14/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0317
# Epoch 15/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0311
# Epoch 16/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0301
# Epoch 17/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0290
# Epoch 18/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0277
# Epoch 19/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0265
# Epoch 20/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0251
# Epoch 21/40
# 8/8 - 0s - loss: 0.0025 - ariel_challenge_metric_num: 0.0234
# Epoch 22/40
# 8/8 - 0s - loss: 0.0021 - ariel_challenge_metric_num: 0.0209
# Epoch 23/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0166
# Epoch 24/40
# 8/8 - 0s - loss: 7.4200e-04 - ariel_challenge_metric_num: 0.0114
# Epoch 25/40
# 8/8 - 0s - loss: 3.4948e-04 - ariel_challenge_metric_num: 0.0078
# Epoch 26/40
# 8/8 - 0s - loss: 3.3020e-04 - ariel_challenge_metric_num: 0.0076
# Epoch 27/40
# 8/8 - 0s - loss: 3.2835e-04 - ariel_challenge_metric_num: 0.0077
# Epoch 28/40
# 8/8 - 0s - loss: 3.0228e-04 - ariel_challenge_metric_num: 0.0072
# Epoch 29/40
# 8/8 - 0s - loss: 2.7667e-04 - ariel_challenge_metric_num: 0.0069
# Epoch 30/40
# 8/8 - 0s - loss: 2.6074e-04 - ariel_challenge_metric_num: 0.0066
# Epoch 31/40
# 8/8 - 0s - loss: 2.3304e-04 - ariel_challenge_metric_num: 0.0062
# Epoch 32/40
# 8/8 - 0s - loss: 1.8603e-04 - ariel_challenge_metric_num: 0.0054
# Epoch 33/40
# 8/8 - 0s - loss: 1.5179e-04 - ariel_challenge_metric_num: 0.0046
# Epoch 34/40
# 8/8 - 0s - loss: 1.4197e-04 - ariel_challenge_metric_num: 0.0045
# Epoch 35/40
# 8/8 - 0s - loss: 1.3596e-04 - ariel_challenge_metric_num: 0.0044
# Epoch 36/40
# 8/8 - 0s - loss: 1.2409e-04 - ariel_challenge_metric_num: 0.0042
# Epoch 37/40
# 8/8 - 0s - loss: 1.1713e-04 - ariel_challenge_metric_num: 0.0039
# Epoch 38/40
# 8/8 - 0s - loss: 1.0799e-04 - ariel_challenge_metric_num: 0.0035
# Epoch 39/40
# 8/8 - 0s - loss: 1.0368e-04 - ariel_challenge_metric_num: 0.0034
# Epoch 40/40
# 8/8 - 0s - loss: 1.0236e-04 - ariel_challenge_metric_num: 0.0034
#
# Table 3 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1614 - ariel_challenge_metric_num: 0.1539
# Epoch 2/40
# 8/8 - 0s - loss: 0.0301 - ariel_challenge_metric_num: 0.0597
# Epoch 3/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0271
# Epoch 4/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0306
# Epoch 5/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0318
# Epoch 6/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0320
# Epoch 7/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0321
# Epoch 8/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0320
# Epoch 9/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0318
# Epoch 10/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0316
# Epoch 11/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0313
# Epoch 12/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0309
# Epoch 13/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0302
# Epoch 14/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0294
# Epoch 15/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0283
# Epoch 16/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0272
# Epoch 17/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0259
# Epoch 18/40
# 8/8 - 0s - loss: 0.0026 - ariel_challenge_metric_num: 0.0241
# Epoch 19/40
# 8/8 - 0s - loss: 0.0022 - ariel_challenge_metric_num: 0.0216
# Epoch 20/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0168
# Epoch 21/40
# 8/8 - 0s - loss: 6.2162e-04 - ariel_challenge_metric_num: 0.0104
# Epoch 22/40
# 8/8 - 0s - loss: 3.4520e-04 - ariel_challenge_metric_num: 0.0076
# Epoch 23/40
# 8/8 - 0s - loss: 2.7461e-04 - ariel_challenge_metric_num: 0.0067
# Epoch 24/40
# 8/8 - 0s - loss: 3.4984e-04 - ariel_challenge_metric_num: 0.0079
# Epoch 25/40
# 8/8 - 0s - loss: 4.4700e-04 - ariel_challenge_metric_num: 0.0085
# Epoch 26/40
# 8/8 - 0s - loss: 4.2359e-04 - ariel_challenge_metric_num: 0.0086
# Epoch 27/40
# 8/8 - 0s - loss: 2.7245e-04 - ariel_challenge_metric_num: 0.0067
# Epoch 28/40
# 8/8 - 0s - loss: 2.0833e-04 - ariel_challenge_metric_num: 0.0056
# Epoch 29/40
# 8/8 - 0s - loss: 1.6538e-04 - ariel_challenge_metric_num: 0.0051
# Epoch 30/40
# 8/8 - 0s - loss: 1.3536e-04 - ariel_challenge_metric_num: 0.0044
# Epoch 31/40
# 8/8 - 0s - loss: 1.1591e-04 - ariel_challenge_metric_num: 0.0036
# Epoch 32/40
# 8/8 - 0s - loss: 1.0466e-04 - ariel_challenge_metric_num: 0.0035
# Epoch 33/40
# 8/8 - 0s - loss: 9.7381e-05 - ariel_challenge_metric_num: 0.0033
# Epoch 34/40
# 8/8 - 0s - loss: 9.1447e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 35/40
# 8/8 - 0s - loss: 8.5848e-05 - ariel_challenge_metric_num: 0.0030
# Epoch 36/40
# 8/8 - 0s - loss: 8.2476e-05 - ariel_challenge_metric_num: 0.0030
# Epoch 37/40
# 8/8 - 0s - loss: 7.7528e-05 - ariel_challenge_metric_num: 0.0029
# Epoch 38/40
# 8/8 - 0s - loss: 7.3613e-05 - ariel_challenge_metric_num: 0.0028
# Epoch 39/40
# 8/8 - 0s - loss: 7.1077e-05 - ariel_challenge_metric_num: 0.0027
# Epoch 40/40
# 8/8 - 0s - loss: 6.8344e-05 - ariel_challenge_metric_num: 0.0026
#
# Table 4 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1591 - ariel_challenge_metric_num: 0.1618
# Epoch 2/40
# 8/8 - 0s - loss: 0.0273 - ariel_challenge_metric_num: 0.0619
# Epoch 3/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0291
# Epoch 4/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0320
# Epoch 5/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0334
# Epoch 6/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0338
# Epoch 7/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0338
# Epoch 8/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0336
# Epoch 9/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0333
# Epoch 10/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0329
# Epoch 11/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0322
# Epoch 12/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0313
# Epoch 13/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0303
# Epoch 14/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0292
# Epoch 15/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0278
# Epoch 16/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0263
# Epoch 17/40
# 8/8 - 0s - loss: 0.0026 - ariel_challenge_metric_num: 0.0245
# Epoch 18/40
# 8/8 - 0s - loss: 0.0021 - ariel_challenge_metric_num: 0.0216
# Epoch 19/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0185
# Epoch 20/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0158
# Epoch 21/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0151
# Epoch 22/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0146
# Epoch 23/40
# 8/8 - 0s - loss: 9.7828e-04 - ariel_challenge_metric_num: 0.0136
# Epoch 24/40
# 8/8 - 0s - loss: 7.0436e-04 - ariel_challenge_metric_num: 0.0116
# Epoch 25/40
# 8/8 - 0s - loss: 5.4249e-04 - ariel_challenge_metric_num: 0.0103
# Epoch 26/40
# 8/8 - 0s - loss: 5.1012e-04 - ariel_challenge_metric_num: 0.0102
# Epoch 27/40
# 8/8 - 0s - loss: 4.7286e-04 - ariel_challenge_metric_num: 0.0096
# Epoch 28/40
# 8/8 - 0s - loss: 4.5104e-04 - ariel_challenge_metric_num: 0.0092
# Epoch 29/40
# 8/8 - 0s - loss: 4.0701e-04 - ariel_challenge_metric_num: 0.0087
# Epoch 30/40
# 8/8 - 0s - loss: 3.7424e-04 - ariel_challenge_metric_num: 0.0085
# Epoch 31/40
# 8/8 - 0s - loss: 3.4771e-04 - ariel_challenge_metric_num: 0.0080
# Epoch 32/40
# 8/8 - 0s - loss: 3.2317e-04 - ariel_challenge_metric_num: 0.0076
# Epoch 33/40
# 8/8 - 0s - loss: 3.0732e-04 - ariel_challenge_metric_num: 0.0074
# Epoch 34/40
# 8/8 - 0s - loss: 3.0305e-04 - ariel_challenge_metric_num: 0.0073
# Epoch 35/40
# 8/8 - 0s - loss: 2.9944e-04 - ariel_challenge_metric_num: 0.0072
# Epoch 36/40
# 8/8 - 0s - loss: 2.9214e-04 - ariel_challenge_metric_num: 0.0071
# Epoch 37/40
# 8/8 - 0s - loss: 2.8451e-04 - ariel_challenge_metric_num: 0.0069
# Epoch 38/40
# 8/8 - 0s - loss: 2.7958e-04 - ariel_challenge_metric_num: 0.0068
# Epoch 39/40
# 8/8 - 0s - loss: 2.7626e-04 - ariel_challenge_metric_num: 0.0068
# Epoch 40/40
# 8/8 - 0s - loss: 2.7144e-04 - ariel_challenge_metric_num: 0.0067
#
# Table 5 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1559 - ariel_challenge_metric_num: 0.1525
# Epoch 2/40
# 8/8 - 0s - loss: 0.0235 - ariel_challenge_metric_num: 0.0542
# Epoch 3/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0280
# Epoch 4/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0312
# Epoch 5/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0324
# Epoch 6/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0327
# Epoch 7/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0327
# Epoch 8/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0325
# Epoch 9/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0323
# Epoch 10/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0320
# Epoch 11/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0315
# Epoch 12/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0307
# Epoch 13/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0297
# Epoch 14/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0286
# Epoch 15/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0274
# Epoch 16/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0262
# Epoch 17/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0247
# Epoch 18/40
# 8/8 - 0s - loss: 0.0023 - ariel_challenge_metric_num: 0.0226
# Epoch 19/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0193
# Epoch 20/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0160
# Epoch 21/40
# 8/8 - 0s - loss: 0.0010 - ariel_challenge_metric_num: 0.0131
# Epoch 22/40
# 8/8 - 0s - loss: 8.1138e-04 - ariel_challenge_metric_num: 0.0117
# Epoch 23/40
# 8/8 - 0s - loss: 5.3476e-04 - ariel_challenge_metric_num: 0.0095
# Epoch 24/40
# 8/8 - 0s - loss: 3.8382e-04 - ariel_challenge_metric_num: 0.0082
# Epoch 25/40
# 8/8 - 0s - loss: 3.5655e-04 - ariel_challenge_metric_num: 0.0078
# Epoch 26/40
# 8/8 - 0s - loss: 3.2054e-04 - ariel_challenge_metric_num: 0.0074
# Epoch 27/40
# 8/8 - 0s - loss: 3.0879e-04 - ariel_challenge_metric_num: 0.0073
# Epoch 28/40
# 8/8 - 0s - loss: 2.8980e-04 - ariel_challenge_metric_num: 0.0070
# Epoch 29/40
# 8/8 - 0s - loss: 2.7582e-04 - ariel_challenge_metric_num: 0.0066
# Epoch 30/40
# 8/8 - 0s - loss: 2.5957e-04 - ariel_challenge_metric_num: 0.0063
# Epoch 31/40
# 8/8 - 0s - loss: 2.4387e-04 - ariel_challenge_metric_num: 0.0062
# Epoch 32/40
# 8/8 - 0s - loss: 2.3148e-04 - ariel_challenge_metric_num: 0.0058
# Epoch 33/40
# 8/8 - 0s - loss: 2.0876e-04 - ariel_challenge_metric_num: 0.0057
# Epoch 34/40
# 8/8 - 0s - loss: 1.9532e-04 - ariel_challenge_metric_num: 0.0055
# Epoch 35/40
# 8/8 - 0s - loss: 2.1002e-04 - ariel_challenge_metric_num: 0.0060
# Epoch 36/40
# 8/8 - 0s - loss: 1.7638e-04 - ariel_challenge_metric_num: 0.0049
# Epoch 37/40
# 8/8 - 0s - loss: 1.9809e-04 - ariel_challenge_metric_num: 0.0057
# Epoch 38/40
# 8/8 - 0s - loss: 2.2924e-04 - ariel_challenge_metric_num: 0.0062
# Epoch 39/40
# 8/8 - 0s - loss: 1.7259e-04 - ariel_challenge_metric_num: 0.0051
# Epoch 40/40
# 8/8 - 0s - loss: 1.4775e-04 - ariel_challenge_metric_num: 0.0046
#
# Table 6 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1675 - ariel_challenge_metric_num: 0.1621
# Epoch 2/40
# 8/8 - 0s - loss: 0.0390 - ariel_challenge_metric_num: 0.0701
# Epoch 3/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0276
# Epoch 4/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0303
# Epoch 5/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0320
# Epoch 6/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0325
# Epoch 7/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0325
# Epoch 8/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0324
# Epoch 9/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0321
# Epoch 10/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0318
# Epoch 11/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0312
# Epoch 12/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0306
# Epoch 13/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0297
# Epoch 14/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0288
# Epoch 15/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0277
# Epoch 16/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0263
# Epoch 17/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0248
# Epoch 18/40
# 8/8 - 0s - loss: 0.0024 - ariel_challenge_metric_num: 0.0229
# Epoch 19/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0200
# Epoch 20/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0170
# Epoch 21/40
# 8/8 - 0s - loss: 0.0013 - ariel_challenge_metric_num: 0.0147
# Epoch 22/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0139
# Epoch 23/40
# 8/8 - 0s - loss: 0.0010 - ariel_challenge_metric_num: 0.0134
# Epoch 24/40
# 8/8 - 0s - loss: 8.5688e-04 - ariel_challenge_metric_num: 0.0123
# Epoch 25/40
# 8/8 - 0s - loss: 5.7364e-04 - ariel_challenge_metric_num: 0.0100
# Epoch 26/40
# 8/8 - 0s - loss: 3.9950e-04 - ariel_challenge_metric_num: 0.0084
# Epoch 27/40
# 8/8 - 0s - loss: 3.4749e-04 - ariel_challenge_metric_num: 0.0076
# Epoch 28/40
# 8/8 - 0s - loss: 3.2439e-04 - ariel_challenge_metric_num: 0.0075
# Epoch 29/40
# 8/8 - 0s - loss: 3.1207e-04 - ariel_challenge_metric_num: 0.0073
# Epoch 30/40
# 8/8 - 0s - loss: 2.8987e-04 - ariel_challenge_metric_num: 0.0070
# Epoch 31/40
# 8/8 - 0s - loss: 3.0635e-04 - ariel_challenge_metric_num: 0.0074
# Epoch 32/40
# 8/8 - 0s - loss: 2.6556e-04 - ariel_challenge_metric_num: 0.0068
# Epoch 33/40
# 8/8 - 0s - loss: 2.2705e-04 - ariel_challenge_metric_num: 0.0058
# Epoch 34/40
# 8/8 - 0s - loss: 2.1807e-04 - ariel_challenge_metric_num: 0.0061
# Epoch 35/40
# 8/8 - 0s - loss: 1.8706e-04 - ariel_challenge_metric_num: 0.0052
# Epoch 36/40
# 8/8 - 0s - loss: 1.6540e-04 - ariel_challenge_metric_num: 0.0048
# Epoch 37/40
# 8/8 - 0s - loss: 1.4996e-04 - ariel_challenge_metric_num: 0.0045
# Epoch 38/40
# 8/8 - 0s - loss: 1.3994e-04 - ariel_challenge_metric_num: 0.0043
# Epoch 39/40
# 8/8 - 0s - loss: 1.3302e-04 - ariel_challenge_metric_num: 0.0042
# Epoch 40/40
# 8/8 - 0s - loss: 1.2658e-04 - ariel_challenge_metric_num: 0.0042
#
# Table 7 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1630 - ariel_challenge_metric_num: 0.1640
# Epoch 2/40
# 8/8 - 0s - loss: 0.0328 - ariel_challenge_metric_num: 0.0680
# Epoch 3/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0292
# Epoch 4/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0320
# Epoch 5/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0336
# Epoch 6/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0340
# Epoch 7/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0340
# Epoch 8/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0339
# Epoch 9/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0336
# Epoch 10/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0332
# Epoch 11/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0326
# Epoch 12/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0318
# Epoch 13/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0309
# Epoch 14/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0299
# Epoch 15/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0288
# Epoch 16/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0274
# Epoch 17/40
# 8/8 - 0s - loss: 0.0028 - ariel_challenge_metric_num: 0.0258
# Epoch 18/40
# 8/8 - 0s - loss: 0.0025 - ariel_challenge_metric_num: 0.0237
# Epoch 19/40
# 8/8 - 0s - loss: 0.0020 - ariel_challenge_metric_num: 0.0204
# Epoch 20/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0169
# Epoch 21/40
# 8/8 - 0s - loss: 0.0013 - ariel_challenge_metric_num: 0.0151
# Epoch 22/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0142
# Epoch 23/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0137
# Epoch 24/40
# 8/8 - 0s - loss: 9.2542e-04 - ariel_challenge_metric_num: 0.0127
# Epoch 25/40
# 8/8 - 0s - loss: 6.8296e-04 - ariel_challenge_metric_num: 0.0110
# Epoch 26/40
# 8/8 - 0s - loss: 4.3872e-04 - ariel_challenge_metric_num: 0.0087
# Epoch 27/40
# 8/8 - 0s - loss: 3.7244e-04 - ariel_challenge_metric_num: 0.0082
# Epoch 28/40
# 8/8 - 0s - loss: 3.1541e-04 - ariel_challenge_metric_num: 0.0073
# Epoch 29/40
# 8/8 - 0s - loss: 2.8411e-04 - ariel_challenge_metric_num: 0.0068
# Epoch 30/40
# 8/8 - 0s - loss: 2.6264e-04 - ariel_challenge_metric_num: 0.0067
# Epoch 31/40
# 8/8 - 0s - loss: 2.4158e-04 - ariel_challenge_metric_num: 0.0063
# Epoch 32/40
# 8/8 - 0s - loss: 2.1885e-04 - ariel_challenge_metric_num: 0.0061
# Epoch 33/40
# 8/8 - 0s - loss: 2.0169e-04 - ariel_challenge_metric_num: 0.0056
# Epoch 34/40
# 8/8 - 0s - loss: 1.9036e-04 - ariel_challenge_metric_num: 0.0057
# Epoch 35/40
# 8/8 - 0s - loss: 2.2147e-04 - ariel_challenge_metric_num: 0.0063
# Epoch 36/40
# 8/8 - 0s - loss: 1.8121e-04 - ariel_challenge_metric_num: 0.0053
# Epoch 37/40
# 8/8 - 0s - loss: 1.5203e-04 - ariel_challenge_metric_num: 0.0048
# Epoch 38/40
# 8/8 - 0s - loss: 1.3631e-04 - ariel_challenge_metric_num: 0.0043
# Epoch 39/40
# 8/8 - 0s - loss: 1.2474e-04 - ariel_challenge_metric_num: 0.0042
# Epoch 40/40
# 8/8 - 0s - loss: 1.1722e-04 - ariel_challenge_metric_num: 0.0040
#
# Table 8 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1665 - ariel_challenge_metric_num: 0.1627
# Epoch 2/40
# 8/8 - 0s - loss: 0.0420 - ariel_challenge_metric_num: 0.0745
# Epoch 3/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0290
# Epoch 4/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0321
# Epoch 5/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0338
# Epoch 6/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0342
# Epoch 7/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0342
# Epoch 8/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0341
# Epoch 9/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0339
# Epoch 10/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0337
# Epoch 11/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0334
# Epoch 12/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0330
# Epoch 13/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0325
# Epoch 14/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0319
# Epoch 15/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0311
# Epoch 16/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0305
# Epoch 17/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0296
# Epoch 18/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0287
# Epoch 19/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0273
# Epoch 20/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0256
# Epoch 21/40
# 8/8 - 0s - loss: 0.0023 - ariel_challenge_metric_num: 0.0226
# Epoch 22/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0175
# Epoch 23/40
# 8/8 - 0s - loss: 9.9328e-04 - ariel_challenge_metric_num: 0.0131
# Epoch 24/40
# 8/8 - 0s - loss: 9.0850e-04 - ariel_challenge_metric_num: 0.0124
# Epoch 25/40
# 8/8 - 0s - loss: 7.7071e-04 - ariel_challenge_metric_num: 0.0117
# Epoch 26/40
# 8/8 - 0s - loss: 6.2400e-04 - ariel_challenge_metric_num: 0.0106
# Epoch 27/40
# 8/8 - 0s - loss: 4.5142e-04 - ariel_challenge_metric_num: 0.0089
# Epoch 28/40
# 8/8 - 0s - loss: 3.1638e-04 - ariel_challenge_metric_num: 0.0076
# Epoch 29/40
# 8/8 - 0s - loss: 2.5376e-04 - ariel_challenge_metric_num: 0.0070
# Epoch 30/40
# 8/8 - 0s - loss: 2.2163e-04 - ariel_challenge_metric_num: 0.0064
# Epoch 31/40
# 8/8 - 0s - loss: 1.6656e-04 - ariel_challenge_metric_num: 0.0053
# Epoch 32/40
# 8/8 - 0s - loss: 1.4605e-04 - ariel_challenge_metric_num: 0.0049
# Epoch 33/40
# 8/8 - 0s - loss: 1.2190e-04 - ariel_challenge_metric_num: 0.0043
# Epoch 34/40
# 8/8 - 0s - loss: 1.1038e-04 - ariel_challenge_metric_num: 0.0039
# Epoch 35/40
# 8/8 - 0s - loss: 9.9335e-05 - ariel_challenge_metric_num: 0.0036
# Epoch 36/40
# 8/8 - 0s - loss: 9.1721e-05 - ariel_challenge_metric_num: 0.0034
# Epoch 37/40
# 8/8 - 0s - loss: 8.5169e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 38/40
# 8/8 - 0s - loss: 8.1974e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 39/40
# 8/8 - 0s - loss: 7.7516e-05 - ariel_challenge_metric_num: 0.0029
# Epoch 40/40
# 8/8 - 0s - loss: 7.3575e-05 - ariel_challenge_metric_num: 0.0028
#
# Table 9 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1600 - ariel_challenge_metric_num: 0.1577
# Epoch 2/40
# 8/8 - 0s - loss: 0.0303 - ariel_challenge_metric_num: 0.0624
# Epoch 3/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0291
# Epoch 4/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0334
# Epoch 5/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0344
# Epoch 6/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0347
# Epoch 7/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0347
# Epoch 8/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0347
# Epoch 9/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0346
# Epoch 10/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0345
# Epoch 11/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0343
# Epoch 12/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0340
# Epoch 13/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0338
# Epoch 14/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0334
# Epoch 15/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0330
# Epoch 16/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0324
# Epoch 17/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0316
# Epoch 18/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0306
# Epoch 19/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0293
# Epoch 20/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0277
# Epoch 21/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0255
# Epoch 22/40
# 8/8 - 0s - loss: 0.0022 - ariel_challenge_metric_num: 0.0223
# Epoch 23/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0181
# Epoch 24/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0147
# Epoch 25/40
# 8/8 - 0s - loss: 9.4385e-04 - ariel_challenge_metric_num: 0.0129
# Epoch 26/40
# 8/8 - 0s - loss: 7.9255e-04 - ariel_challenge_metric_num: 0.0119
# Epoch 27/40
# 8/8 - 0s - loss: 5.8824e-04 - ariel_challenge_metric_num: 0.0102
# Epoch 28/40
# 8/8 - 0s - loss: 3.6959e-04 - ariel_challenge_metric_num: 0.0078
# Epoch 29/40
# 8/8 - 0s - loss: 2.4619e-04 - ariel_challenge_metric_num: 0.0064
# Epoch 30/40
# 8/8 - 0s - loss: 1.9531e-04 - ariel_challenge_metric_num: 0.0059
# Epoch 31/40
# 8/8 - 0s - loss: 1.3271e-04 - ariel_challenge_metric_num: 0.0045
# Epoch 32/40
# 8/8 - 0s - loss: 1.0998e-04 - ariel_challenge_metric_num: 0.0040
# Epoch 33/40
# 8/8 - 0s - loss: 1.0243e-04 - ariel_challenge_metric_num: 0.0037
# Epoch 34/40
# 8/8 - 0s - loss: 9.3149e-05 - ariel_challenge_metric_num: 0.0034
# Epoch 35/40
# 8/8 - 0s - loss: 8.8522e-05 - ariel_challenge_metric_num: 0.0033
# Epoch 36/40
# 8/8 - 0s - loss: 9.6975e-05 - ariel_challenge_metric_num: 0.0038
# Epoch 37/40
# 8/8 - 0s - loss: 1.0855e-04 - ariel_challenge_metric_num: 0.0041
# Epoch 38/40
# 8/8 - 0s - loss: 9.7932e-05 - ariel_challenge_metric_num: 0.0038
# Epoch 39/40
# 8/8 - 0s - loss: 8.5186e-05 - ariel_challenge_metric_num: 0.0034
# Epoch 40/40
# 8/8 - 0s - loss: 7.4091e-05 - ariel_challenge_metric_num: 0.0030
#
# Table 10 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1652 - ariel_challenge_metric_num: 0.1614
# Epoch 2/40
# 8/8 - 0s - loss: 0.0348 - ariel_challenge_metric_num: 0.0660
# Epoch 3/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0278
# Epoch 4/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0317
# Epoch 5/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0332
# Epoch 6/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0336
# Epoch 7/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0336
# Epoch 8/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0335
# Epoch 9/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0333
# Epoch 10/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0330
# Epoch 11/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0326
# Epoch 12/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0321
# Epoch 13/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0314
# Epoch 14/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0306
# Epoch 15/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0295
# Epoch 16/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0282
# Epoch 17/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0268
# Epoch 18/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0250
# Epoch 19/40
# 8/8 - 0s - loss: 0.0023 - ariel_challenge_metric_num: 0.0228
# Epoch 20/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0199
# Epoch 21/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0167
# Epoch 22/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0149
# Epoch 23/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0145
# Epoch 24/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0139
# Epoch 25/40
# 8/8 - 0s - loss: 9.4108e-04 - ariel_challenge_metric_num: 0.0130
# Epoch 26/40
# 8/8 - 0s - loss: 7.4832e-04 - ariel_challenge_metric_num: 0.0117
# Epoch 27/40
# 8/8 - 0s - loss: 4.8687e-04 - ariel_challenge_metric_num: 0.0094
# Epoch 28/40
# 8/8 - 0s - loss: 3.5286e-04 - ariel_challenge_metric_num: 0.0079
# Epoch 29/40
# 8/8 - 0s - loss: 3.0798e-04 - ariel_challenge_metric_num: 0.0072
# Epoch 30/40
# 8/8 - 0s - loss: 2.8534e-04 - ariel_challenge_metric_num: 0.0069
# Epoch 31/40
# 8/8 - 0s - loss: 2.6675e-04 - ariel_challenge_metric_num: 0.0065
# Epoch 32/40
# 8/8 - 0s - loss: 2.4382e-04 - ariel_challenge_metric_num: 0.0062
# Epoch 33/40
# 8/8 - 0s - loss: 2.2012e-04 - ariel_challenge_metric_num: 0.0058
# Epoch 34/40
# 8/8 - 0s - loss: 1.9600e-04 - ariel_challenge_metric_num: 0.0054
# Epoch 35/40
# 8/8 - 0s - loss: 1.8308e-04 - ariel_challenge_metric_num: 0.0053
# Epoch 36/40
# 8/8 - 0s - loss: 1.7109e-04 - ariel_challenge_metric_num: 0.0052
# Epoch 37/40
# 8/8 - 0s - loss: 1.4789e-04 - ariel_challenge_metric_num: 0.0047
# Epoch 38/40
# 8/8 - 0s - loss: 1.3465e-04 - ariel_challenge_metric_num: 0.0043
# Epoch 39/40
# 8/8 - 0s - loss: 1.2115e-04 - ariel_challenge_metric_num: 0.0042
# Epoch 40/40
# 8/8 - 0s - loss: 1.0805e-04 - ariel_challenge_metric_num: 0.0038
#
# Table 11 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1648 - ariel_challenge_metric_num: 0.1573
# Epoch 2/40
# 8/8 - 0s - loss: 0.0416 - ariel_challenge_metric_num: 0.0722
# Epoch 3/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0281
# Epoch 4/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0317
# Epoch 5/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0332
# Epoch 6/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0336
# Epoch 7/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0336
# Epoch 8/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0336
# Epoch 9/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0335
# Epoch 10/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0333
# Epoch 11/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0331
# Epoch 12/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0328
# Epoch 13/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0325
# Epoch 14/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0319
# Epoch 15/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0312
# Epoch 16/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0302
# Epoch 17/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0290
# Epoch 18/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0278
# Epoch 19/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0267
# Epoch 20/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0254
# Epoch 21/40
# 8/8 - 0s - loss: 0.0025 - ariel_challenge_metric_num: 0.0236
# Epoch 22/40
# 8/8 - 0s - loss: 0.0021 - ariel_challenge_metric_num: 0.0209
# Epoch 23/40
# 8/8 - 0s - loss: 0.0013 - ariel_challenge_metric_num: 0.0156
# Epoch 24/40
# 8/8 - 0s - loss: 5.0925e-04 - ariel_challenge_metric_num: 0.0094
# Epoch 25/40
# 8/8 - 0s - loss: 3.4884e-04 - ariel_challenge_metric_num: 0.0082
# Epoch 26/40
# 8/8 - 0s - loss: 3.4271e-04 - ariel_challenge_metric_num: 0.0075
# Epoch 27/40
# 8/8 - 0s - loss: 3.1022e-04 - ariel_challenge_metric_num: 0.0077
# Epoch 28/40
# 8/8 - 0s - loss: 4.1498e-04 - ariel_challenge_metric_num: 0.0085
# Epoch 29/40
# 8/8 - 0s - loss: 2.8766e-04 - ariel_challenge_metric_num: 0.0072
# Epoch 30/40
# 8/8 - 0s - loss: 1.8510e-04 - ariel_challenge_metric_num: 0.0059
# Epoch 31/40
# 8/8 - 0s - loss: 2.9205e-04 - ariel_challenge_metric_num: 0.0070
# Epoch 32/40
# 8/8 - 0s - loss: 1.5669e-04 - ariel_challenge_metric_num: 0.0056
# Epoch 33/40
# 8/8 - 0s - loss: 1.1848e-04 - ariel_challenge_metric_num: 0.0042
# Epoch 34/40
# 8/8 - 0s - loss: 9.9053e-05 - ariel_challenge_metric_num: 0.0037
# Epoch 35/40
# 8/8 - 0s - loss: 9.0341e-05 - ariel_challenge_metric_num: 0.0034
# Epoch 36/40
# 8/8 - 0s - loss: 8.3304e-05 - ariel_challenge_metric_num: 0.0033
# Epoch 37/40
# 8/8 - 0s - loss: 7.9196e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 38/40
# 8/8 - 0s - loss: 7.6703e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 39/40
# 8/8 - 0s - loss: 7.2338e-05 - ariel_challenge_metric_num: 0.0029
# Epoch 40/40
# 8/8 - 0s - loss: 6.6148e-05 - ariel_challenge_metric_num: 0.0026
#
# Table 12 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1644 - ariel_challenge_metric_num: 0.1595
# Epoch 2/40
# 8/8 - 0s - loss: 0.0341 - ariel_challenge_metric_num: 0.0663
# Epoch 3/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0282
# Epoch 4/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0320
# Epoch 5/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0332
# Epoch 6/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0335
# Epoch 7/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0335
# Epoch 8/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0335
# Epoch 9/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0334
# Epoch 10/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0332
# Epoch 11/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0330
# Epoch 12/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0328
# Epoch 13/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0324
# Epoch 14/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0321
# Epoch 15/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0316
# Epoch 16/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0309
# Epoch 17/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0300
# Epoch 18/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0291
# Epoch 19/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0278
# Epoch 20/40
# 8/8 - 0s - loss: 0.0029 - ariel_challenge_metric_num: 0.0264
# Epoch 21/40
# 8/8 - 0s - loss: 0.0025 - ariel_challenge_metric_num: 0.0239
# Epoch 22/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0201
# Epoch 23/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0145
# Epoch 24/40
# 8/8 - 0s - loss: 8.1207e-04 - ariel_challenge_metric_num: 0.0106
# Epoch 25/40
# 8/8 - 0s - loss: 8.5988e-04 - ariel_challenge_metric_num: 0.0114
# Epoch 26/40
# 8/8 - 0s - loss: 5.0839e-04 - ariel_challenge_metric_num: 0.0089
# Epoch 27/40
# 8/8 - 0s - loss: 3.2112e-04 - ariel_challenge_metric_num: 0.0070
# Epoch 28/40
# 8/8 - 0s - loss: 1.7630e-04 - ariel_challenge_metric_num: 0.0050
# Epoch 29/40
# 8/8 - 0s - loss: 1.3872e-04 - ariel_challenge_metric_num: 0.0047
# Epoch 30/40
# 8/8 - 0s - loss: 1.1212e-04 - ariel_challenge_metric_num: 0.0039
# Epoch 31/40
# 8/8 - 0s - loss: 1.0355e-04 - ariel_challenge_metric_num: 0.0036
# Epoch 32/40
# 8/8 - 0s - loss: 9.3780e-05 - ariel_challenge_metric_num: 0.0032
# Epoch 33/40
# 8/8 - 0s - loss: 8.8804e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 34/40
# 8/8 - 0s - loss: 8.6174e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 35/40
# 8/8 - 0s - loss: 8.3511e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 36/40
# 8/8 - 0s - loss: 8.0077e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 37/40
# 8/8 - 0s - loss: 8.5949e-05 - ariel_challenge_metric_num: 0.0033
# Epoch 38/40
# 8/8 - 0s - loss: 7.9112e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 39/40
# 8/8 - 0s - loss: 7.5972e-05 - ariel_challenge_metric_num: 0.0029
# Epoch 40/40
# 8/8 - 0s - loss: 6.9441e-05 - ariel_challenge_metric_num: 0.0026
#
# Table 13 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1586 - ariel_challenge_metric_num: 0.1593
# Epoch 2/40
# 8/8 - 0s - loss: 0.0239 - ariel_challenge_metric_num: 0.0553
# Epoch 3/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0280
# Epoch 4/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0314
# Epoch 5/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0327
# Epoch 6/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0329
# Epoch 7/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0329
# Epoch 8/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0327
# Epoch 9/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0324
# Epoch 10/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0319
# Epoch 11/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0312
# Epoch 12/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0302
# Epoch 13/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0289
# Epoch 14/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0271
# Epoch 15/40
# 8/8 - 0s - loss: 0.0027 - ariel_challenge_metric_num: 0.0249
# Epoch 16/40
# 8/8 - 0s - loss: 0.0023 - ariel_challenge_metric_num: 0.0223
# Epoch 17/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0192
# Epoch 18/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0166
# Epoch 19/40
# 8/8 - 0s - loss: 0.0013 - ariel_challenge_metric_num: 0.0148
# Epoch 20/40
# 8/8 - 0s - loss: 0.0013 - ariel_challenge_metric_num: 0.0146
# Epoch 21/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0134
# Epoch 22/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0125
# Epoch 23/40
# 8/8 - 0s - loss: 0.0010 - ariel_challenge_metric_num: 0.0113
# Epoch 24/40
# 8/8 - 0s - loss: 9.5812e-04 - ariel_challenge_metric_num: 0.0110
# Epoch 25/40
# 8/8 - 0s - loss: 9.0106e-04 - ariel_challenge_metric_num: 0.0106
# Epoch 26/40
# 8/8 - 0s - loss: 8.1678e-04 - ariel_challenge_metric_num: 0.0100
# Epoch 27/40
# 8/8 - 0s - loss: 6.6004e-04 - ariel_challenge_metric_num: 0.0090
# Epoch 28/40
# 8/8 - 0s - loss: 3.6110e-04 - ariel_challenge_metric_num: 0.0069
# Epoch 29/40
# 8/8 - 0s - loss: 1.8863e-04 - ariel_challenge_metric_num: 0.0054
# Epoch 30/40
# 8/8 - 0s - loss: 1.4129e-04 - ariel_challenge_metric_num: 0.0047
# Epoch 31/40
# 8/8 - 0s - loss: 1.0981e-04 - ariel_challenge_metric_num: 0.0039
# Epoch 32/40
# 8/8 - 0s - loss: 1.0323e-04 - ariel_challenge_metric_num: 0.0036
# Epoch 33/40
# 8/8 - 0s - loss: 9.7770e-05 - ariel_challenge_metric_num: 0.0035
# Epoch 34/40
# 8/8 - 0s - loss: 8.9606e-05 - ariel_challenge_metric_num: 0.0034
# Epoch 35/40
# 8/8 - 0s - loss: 8.3984e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 36/40
# 8/8 - 0s - loss: 7.9966e-05 - ariel_challenge_metric_num: 0.0029
# Epoch 37/40
# 8/8 - 0s - loss: 7.7050e-05 - ariel_challenge_metric_num: 0.0028
# Epoch 38/40
# 8/8 - 0s - loss: 7.4009e-05 - ariel_challenge_metric_num: 0.0027
# Epoch 39/40
# 8/8 - 0s - loss: 7.2998e-05 - ariel_challenge_metric_num: 0.0027
# Epoch 40/40
# 8/8 - 0s - loss: 7.0541e-05 - ariel_challenge_metric_num: 0.0025
#
# Table 14 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1620 - ariel_challenge_metric_num: 0.1617
# Epoch 2/40
# 8/8 - 0s - loss: 0.0320 - ariel_challenge_metric_num: 0.0657
# Epoch 3/40
# 8/8 - 0s - loss: 0.0033 - ariel_challenge_metric_num: 0.0282
# Epoch 4/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0320
# Epoch 5/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0334
# Epoch 6/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0337
# Epoch 7/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0337
# Epoch 8/40
# 8/8 - 0s - loss: 0.0041 - ariel_challenge_metric_num: 0.0336
# Epoch 9/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0334
# Epoch 10/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0330
# Epoch 11/40
# 8/8 - 0s - loss: 0.0039 - ariel_challenge_metric_num: 0.0325
# Epoch 12/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0317
# Epoch 13/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0306
# Epoch 14/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0291
# Epoch 15/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0275
# Epoch 16/40
# 8/8 - 0s - loss: 0.0026 - ariel_challenge_metric_num: 0.0249
# Epoch 17/40
# 8/8 - 0s - loss: 0.0020 - ariel_challenge_metric_num: 0.0204
# Epoch 18/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0141
# Epoch 19/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0133
# Epoch 20/40
# 8/8 - 0s - loss: 0.0010 - ariel_challenge_metric_num: 0.0139
# Epoch 21/40
# 8/8 - 0s - loss: 7.8961e-04 - ariel_challenge_metric_num: 0.0113
# Epoch 22/40
# 8/8 - 0s - loss: 5.5639e-04 - ariel_challenge_metric_num: 0.0094
# Epoch 23/40
# 8/8 - 0s - loss: 3.8256e-04 - ariel_challenge_metric_num: 0.0072
# Epoch 24/40
# 8/8 - 0s - loss: 2.6018e-04 - ariel_challenge_metric_num: 0.0059
# Epoch 25/40
# 8/8 - 0s - loss: 1.7534e-04 - ariel_challenge_metric_num: 0.0047
# Epoch 26/40
# 8/8 - 0s - loss: 1.3974e-04 - ariel_challenge_metric_num: 0.0045
# Epoch 27/40
# 8/8 - 0s - loss: 1.2289e-04 - ariel_challenge_metric_num: 0.0043
# Epoch 28/40
# 8/8 - 0s - loss: 1.0430e-04 - ariel_challenge_metric_num: 0.0039
# Epoch 29/40
# 8/8 - 0s - loss: 1.0951e-04 - ariel_challenge_metric_num: 0.0040
# Epoch 30/40
# 8/8 - 0s - loss: 1.0330e-04 - ariel_challenge_metric_num: 0.0038
# Epoch 31/40
# 8/8 - 0s - loss: 8.8670e-05 - ariel_challenge_metric_num: 0.0033
# Epoch 32/40
# 8/8 - 0s - loss: 9.5686e-05 - ariel_challenge_metric_num: 0.0036
# Epoch 33/40
# 8/8 - 0s - loss: 8.9521e-05 - ariel_challenge_metric_num: 0.0035
# Epoch 34/40
# 8/8 - 0s - loss: 8.1189e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 35/40
# 8/8 - 0s - loss: 8.1467e-05 - ariel_challenge_metric_num: 0.0032
# Epoch 36/40
# 8/8 - 0s - loss: 8.3612e-05 - ariel_challenge_metric_num: 0.0033
# Epoch 37/40
# 8/8 - 0s - loss: 7.5915e-05 - ariel_challenge_metric_num: 0.0029
# Epoch 38/40
# 8/8 - 0s - loss: 7.8106e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 39/40
# 8/8 - 0s - loss: 7.3565e-05 - ariel_challenge_metric_num: 0.0029
# Epoch 40/40
# 8/8 - 0s - loss: 6.8806e-05 - ariel_challenge_metric_num: 0.0026
#
# Table 15 completed.
#
# Epoch 1/40
# ...
# Epoch 28/40
# 8/8 - 0s - loss: 1.6839e-04 - ariel_challenge_metric_num: 0.0056
# Epoch 29/40
# 8/8 - 0s - loss: 1.2397e-04 - ariel_challenge_metric_num: 0.0047
# Epoch 30/40
# 8/8 - 0s - loss: 1.0673e-04 - ariel_challenge_metric_num: 0.0042
# Epoch 31/40
# 8/8 - 0s - loss: 1.1030e-04 - ariel_challenge_metric_num: 0.0043
# Epoch 32/40
# 8/8 - 0s - loss: 1.1774e-04 - ariel_challenge_metric_num: 0.0046
# Epoch 33/40
# 8/8 - 0s - loss: 8.4498e-05 - ariel_challenge_metric_num: 0.0036
# Epoch 34/40
# 8/8 - 0s - loss: 8.0267e-05 - ariel_challenge_metric_num: 0.0034
# Epoch 35/40
# 8/8 - 0s - loss: 7.4226e-05 - ariel_challenge_metric_num: 0.0032
# Epoch 36/40
# 8/8 - 0s - loss: 7.9305e-05 - ariel_challenge_metric_num: 0.0034
# Epoch 37/40
# 8/8 - 0s - loss: 7.6660e-05 - ariel_challenge_metric_num: 0.0034
# Epoch 38/40
# 8/8 - 0s - loss: 6.8924e-05 - ariel_challenge_metric_num: 0.0031
# Epoch 39/40
# 8/8 - 0s - loss: 6.0919e-05 - ariel_challenge_metric_num: 0.0028
# Epoch 40/40
# 8/8 - 0s - loss: 6.2738e-05 - ariel_challenge_metric_num: 0.0029
#
# Table 49 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1546 - ariel_challenge_metric_num: 0.1686
# Epoch 2/40
# 8/8 - 0s - loss: 0.0226 - ariel_challenge_metric_num: 0.0635
# Epoch 3/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0199
# Epoch 4/40
# 8/8 - 0s - loss: 0.0026 - ariel_challenge_metric_num: 0.0268
# Epoch 5/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0300
# Epoch 6/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0300
# Epoch 7/40
# 8/8 - 0s - loss: 0.0028 - ariel_challenge_metric_num: 0.0284
# Epoch 8/40
# 8/8 - 0s - loss: 0.0024 - ariel_challenge_metric_num: 0.0257
# Epoch 9/40
# 8/8 - 0s - loss: 0.0021 - ariel_challenge_metric_num: 0.0224
# Epoch 10/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0201
# Epoch 11/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0190
# Epoch 12/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0188
# Epoch 13/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0187
# Epoch 14/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0186
# Epoch 15/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0185
# Epoch 16/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0184
# Epoch 17/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0183
# Epoch 18/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0181
# Epoch 19/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0180
# Epoch 20/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0179
# Epoch 21/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0177
# Epoch 22/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0176
# Epoch 23/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0175
# Epoch 24/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0173
# Epoch 25/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0171
# Epoch 26/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0169
# Epoch 27/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0166
# Epoch 28/40
# 8/8 - 0s - loss: 0.0013 - ariel_challenge_metric_num: 0.0161
# Epoch 29/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0151
# Epoch 30/40
# 8/8 - 0s - loss: 8.1973e-04 - ariel_challenge_metric_num: 0.0131
# Epoch 31/40
# 8/8 - 0s - loss: 6.4116e-04 - ariel_challenge_metric_num: 0.0114
# Epoch 32/40
# 8/8 - 0s - loss: 6.4252e-04 - ariel_challenge_metric_num: 0.0115
# Epoch 33/40
# 8/8 - 0s - loss: 6.1468e-04 - ariel_challenge_metric_num: 0.0111
# Epoch 34/40
# 8/8 - 0s - loss: 5.9650e-04 - ariel_challenge_metric_num: 0.0107
# Epoch 35/40
# 8/8 - 0s - loss: 5.8911e-04 - ariel_challenge_metric_num: 0.0106
# Epoch 36/40
# 8/8 - 0s - loss: 5.8100e-04 - ariel_challenge_metric_num: 0.0105
# Epoch 37/40
# 8/8 - 0s - loss: 5.7960e-04 - ariel_challenge_metric_num: 0.0105
# Epoch 38/40
# 8/8 - 0s - loss: 5.7535e-04 - ariel_challenge_metric_num: 0.0105
# Epoch 39/40
# 8/8 - 0s - loss: 5.7202e-04 - ariel_challenge_metric_num: 0.0104
# Epoch 40/40
# 8/8 - 0s - loss: 5.6995e-04 - ariel_challenge_metric_num: 0.0104
#
# Table 50 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1569 - ariel_challenge_metric_num: 0.1658
# Epoch 2/40
# 8/8 - 0s - loss: 0.0273 - ariel_challenge_metric_num: 0.0650
# Epoch 3/40
# 8/8 - 0s - loss: 0.0037 - ariel_challenge_metric_num: 0.0324
# Epoch 4/40
# 8/8 - 0s - loss: 0.0044 - ariel_challenge_metric_num: 0.0367
# Epoch 5/40
# 8/8 - 0s - loss: 0.0046 - ariel_challenge_metric_num: 0.0379
# Epoch 6/40
# 8/8 - 0s - loss: 0.0046 - ariel_challenge_metric_num: 0.0381
# Epoch 7/40
# 8/8 - 0s - loss: 0.0046 - ariel_challenge_metric_num: 0.0381
# Epoch 8/40
# 8/8 - 0s - loss: 0.0046 - ariel_challenge_metric_num: 0.0380
# Epoch 9/40
# 8/8 - 0s - loss: 0.0045 - ariel_challenge_metric_num: 0.0377
# Epoch 10/40
# 8/8 - 0s - loss: 0.0045 - ariel_challenge_metric_num: 0.0373
# Epoch 11/40
# 8/8 - 0s - loss: 0.0044 - ariel_challenge_metric_num: 0.0367
# Epoch 12/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0359
# Epoch 13/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0345
# Epoch 14/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0326
# Epoch 15/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0305
# Epoch 16/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0283
# Epoch 17/40
# 8/8 - 0s - loss: 0.0024 - ariel_challenge_metric_num: 0.0243
# Epoch 18/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0183
# Epoch 19/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0162
# Epoch 20/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0152
# Epoch 21/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0154
# Epoch 22/40
# 8/8 - 0s - loss: 5.9690e-04 - ariel_challenge_metric_num: 0.0104
# Epoch 23/40
# 8/8 - 0s - loss: 4.2722e-04 - ariel_challenge_metric_num: 0.0090
# Epoch 24/40
# 8/8 - 0s - loss: 3.5368e-04 - ariel_challenge_metric_num: 0.0085
# Epoch 25/40
# 8/8 - 0s - loss: 2.2169e-04 - ariel_challenge_metric_num: 0.0062
# Epoch 26/40
# 8/8 - 0s - loss: 1.9199e-04 - ariel_challenge_metric_num: 0.0056
# Epoch 27/40
# 8/8 - 0s - loss: 2.6555e-04 - ariel_challenge_metric_num: 0.0068
# Epoch 28/40
# 8/8 - 0s - loss: 2.6593e-04 - ariel_challenge_metric_num: 0.0075
# Epoch 29/40
# 8/8 - 0s - loss: 6.0197e-04 - ariel_challenge_metric_num: 0.0101
# Epoch 30/40
# 8/8 - 0s - loss: 2.1078e-04 - ariel_challenge_metric_num: 0.0066
# Epoch 31/40
# 8/8 - 0s - loss: 1.7689e-04 - ariel_challenge_metric_num: 0.0059
# Epoch 32/40
# 8/8 - 0s - loss: 1.3182e-04 - ariel_challenge_metric_num: 0.0045
# Epoch 33/40
# 8/8 - 0s - loss: 1.1696e-04 - ariel_challenge_metric_num: 0.0043
# Epoch 34/40
# 8/8 - 0s - loss: 1.2771e-04 - ariel_challenge_metric_num: 0.0047
# Epoch 35/40
# 8/8 - 0s - loss: 1.8385e-04 - ariel_challenge_metric_num: 0.0052
# Epoch 36/40
# 8/8 - 0s - loss: 2.6727e-04 - ariel_challenge_metric_num: 0.0073
# Epoch 37/40
# 8/8 - 0s - loss: 5.0721e-04 - ariel_challenge_metric_num: 0.0099
# Epoch 38/40
# 8/8 - 0s - loss: 2.2386e-04 - ariel_challenge_metric_num: 0.0070
# Epoch 39/40
# 8/8 - 0s - loss: 1.4419e-04 - ariel_challenge_metric_num: 0.0051
# Epoch 40/40
# 8/8 - 0s - loss: 1.4684e-04 - ariel_challenge_metric_num: 0.0048
#
# Table 51 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1653 - ariel_challenge_metric_num: 0.1770
# Epoch 2/40
# 8/8 - 0s - loss: 0.0450 - ariel_challenge_metric_num: 0.0869
# Epoch 3/40
# 8/8 - 0s - loss: 0.0044 - ariel_challenge_metric_num: 0.0368
# Epoch 4/40
# 8/8 - 0s - loss: 0.0049 - ariel_challenge_metric_num: 0.0410
# Epoch 5/40
# 8/8 - 0s - loss: 0.0052 - ariel_challenge_metric_num: 0.0428
# Epoch 6/40
# 8/8 - 0s - loss: 0.0053 - ariel_challenge_metric_num: 0.0432
# Epoch 7/40
# 8/8 - 0s - loss: 0.0053 - ariel_challenge_metric_num: 0.0433
# Epoch 8/40
# 8/8 - 0s - loss: 0.0053 - ariel_challenge_metric_num: 0.0432
# Epoch 9/40
# 8/8 - 0s - loss: 0.0052 - ariel_challenge_metric_num: 0.0430
# Epoch 10/40
# 8/8 - 0s - loss: 0.0052 - ariel_challenge_metric_num: 0.0428
# Epoch 11/40
# 8/8 - 0s - loss: 0.0051 - ariel_challenge_metric_num: 0.0424
# Epoch 12/40
# 8/8 - 0s - loss: 0.0050 - ariel_challenge_metric_num: 0.0421
# Epoch 13/40
# 8/8 - 0s - loss: 0.0049 - ariel_challenge_metric_num: 0.0415
# Epoch 14/40
# 8/8 - 0s - loss: 0.0048 - ariel_challenge_metric_num: 0.0408
# Epoch 15/40
# 8/8 - 0s - loss: 0.0047 - ariel_challenge_metric_num: 0.0399
# Epoch 16/40
# 8/8 - 0s - loss: 0.0045 - ariel_challenge_metric_num: 0.0386
# Epoch 17/40
# 8/8 - 0s - loss: 0.0043 - ariel_challenge_metric_num: 0.0370
# Epoch 18/40
# 8/8 - 0s - loss: 0.0040 - ariel_challenge_metric_num: 0.0353
# Epoch 19/40
# 8/8 - 0s - loss: 0.0036 - ariel_challenge_metric_num: 0.0335
# Epoch 20/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0304
# Epoch 21/40
# 8/8 - 0s - loss: 0.0026 - ariel_challenge_metric_num: 0.0265
# Epoch 22/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0210
# Epoch 23/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0170
# Epoch 24/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0159
# Epoch 25/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0145
# Epoch 26/40
# 8/8 - 0s - loss: 4.6392e-04 - ariel_challenge_metric_num: 0.0098
# Epoch 27/40
# 8/8 - 0s - loss: 0.0011 - ariel_challenge_metric_num: 0.0145
# Epoch 28/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0169
# Epoch 29/40
# 8/8 - 0s - loss: 9.5008e-04 - ariel_challenge_metric_num: 0.0140
# Epoch 30/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0171
# Epoch 31/40
# 8/8 - 0s - loss: 0.0010 - ariel_challenge_metric_num: 0.0132
# Epoch 32/40
# 8/8 - 0s - loss: 5.7774e-04 - ariel_challenge_metric_num: 0.0122
# Epoch 33/40
# 8/8 - 0s - loss: 5.0433e-04 - ariel_challenge_metric_num: 0.0104
# Epoch 34/40
# 8/8 - 0s - loss: 2.9634e-04 - ariel_challenge_metric_num: 0.0084
# Epoch 35/40
# 8/8 - 0s - loss: 2.0094e-04 - ariel_challenge_metric_num: 0.0063
# Epoch 36/40
# 8/8 - 0s - loss: 1.7155e-04 - ariel_challenge_metric_num: 0.0060
# Epoch 37/40
# 8/8 - 0s - loss: 1.6228e-04 - ariel_challenge_metric_num: 0.0060
# Epoch 38/40
# 8/8 - 0s - loss: 1.2117e-04 - ariel_challenge_metric_num: 0.0048
# Epoch 39/40
# 8/8 - 0s - loss: 1.0236e-04 - ariel_challenge_metric_num: 0.0043
# Epoch 40/40
# 8/8 - 0s - loss: 9.1557e-05 - ariel_challenge_metric_num: 0.0039
#
# Table 52 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1537 - ariel_challenge_metric_num: 0.1739
# Epoch 2/40
# 8/8 - 0s - loss: 0.0223 - ariel_challenge_metric_num: 0.0660
# Epoch 3/40
# 8/8 - 0s - loss: 0.0022 - ariel_challenge_metric_num: 0.0234
# Epoch 4/40
# 8/8 - 0s - loss: 0.0030 - ariel_challenge_metric_num: 0.0302
# Epoch 5/40
# 8/8 - 0s - loss: 0.0035 - ariel_challenge_metric_num: 0.0336
# Epoch 6/40
# 8/8 - 0s - loss: 0.0034 - ariel_challenge_metric_num: 0.0335
# Epoch 7/40
# 8/8 - 0s - loss: 0.0032 - ariel_challenge_metric_num: 0.0318
# Epoch 8/40
# 8/8 - 0s - loss: 0.0028 - ariel_challenge_metric_num: 0.0289
# Epoch 9/40
# 8/8 - 0s - loss: 0.0024 - ariel_challenge_metric_num: 0.0255
# Epoch 10/40
# 8/8 - 0s - loss: 0.0022 - ariel_challenge_metric_num: 0.0230
# Epoch 11/40
# 8/8 - 0s - loss: 0.0021 - ariel_challenge_metric_num: 0.0220
# Epoch 12/40
# 8/8 - 0s - loss: 0.0021 - ariel_challenge_metric_num: 0.0220
# Epoch 13/40
# 8/8 - 0s - loss: 0.0021 - ariel_challenge_metric_num: 0.0218
# Epoch 14/40
# 8/8 - 0s - loss: 0.0020 - ariel_challenge_metric_num: 0.0216
# Epoch 15/40
# 8/8 - 0s - loss: 0.0020 - ariel_challenge_metric_num: 0.0215
# Epoch 16/40
# 8/8 - 0s - loss: 0.0020 - ariel_challenge_metric_num: 0.0214
# Epoch 17/40
# 8/8 - 0s - loss: 0.0020 - ariel_challenge_metric_num: 0.0212
# Epoch 18/40
# 8/8 - 0s - loss: 0.0020 - ariel_challenge_metric_num: 0.0211
# Epoch 19/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0210
# Epoch 20/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0209
# Epoch 21/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0207
# Epoch 22/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0206
# Epoch 23/40
# 8/8 - 0s - loss: 0.0019 - ariel_challenge_metric_num: 0.0204
# Epoch 24/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0203
# Epoch 25/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0201
# Epoch 26/40
# 8/8 - 0s - loss: 0.0018 - ariel_challenge_metric_num: 0.0199
# Epoch 27/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0196
# Epoch 28/40
# 8/8 - 0s - loss: 0.0016 - ariel_challenge_metric_num: 0.0192
# Epoch 29/40
# 8/8 - 0s - loss: 0.0015 - ariel_challenge_metric_num: 0.0185
# Epoch 30/40
# 8/8 - 0s - loss: 0.0013 - ariel_challenge_metric_num: 0.0172
# Epoch 31/40
# 8/8 - 0s - loss: 9.9124e-04 - ariel_challenge_metric_num: 0.0148
# Epoch 32/40
# 8/8 - 0s - loss: 8.8145e-04 - ariel_challenge_metric_num: 0.0137
# Epoch 33/40
# 8/8 - 0s - loss: 8.5800e-04 - ariel_challenge_metric_num: 0.0133
# Epoch 34/40
# 8/8 - 0s - loss: 8.3895e-04 - ariel_challenge_metric_num: 0.0131
# Epoch 35/40
# 8/8 - 0s - loss: 8.2686e-04 - ariel_challenge_metric_num: 0.0129
# Epoch 36/40
# 8/8 - 0s - loss: 8.1731e-04 - ariel_challenge_metric_num: 0.0127
# Epoch 37/40
# 8/8 - 0s - loss: 8.1316e-04 - ariel_challenge_metric_num: 0.0127
# Epoch 38/40
# 8/8 - 0s - loss: 8.0857e-04 - ariel_challenge_metric_num: 0.0126
# Epoch 39/40
# 8/8 - 0s - loss: 8.0626e-04 - ariel_challenge_metric_num: 0.0125
# Epoch 40/40
# 8/8 - 0s - loss: 8.0313e-04 - ariel_challenge_metric_num: 0.0125
#
# Table 53 completed.
#
# Epoch 1/40
# 8/8 - 1s - loss: 0.1670 - ariel_challenge_metric_num: 0.1767
# Epoch 2/40
# 8/8 - 0s - loss: 0.0455 - ariel_challenge_metric_num: 0.0859
# Epoch 3/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0334
# Epoch 4/40
# 8/8 - 0s - loss: 0.0047 - ariel_challenge_metric_num: 0.0399
# Epoch 5/40
# 8/8 - 0s - loss: 0.0050 - ariel_challenge_metric_num: 0.0413
# Epoch 6/40
# 8/8 - 0s - loss: 0.0051 - ariel_challenge_metric_num: 0.0416
# Epoch 7/40
# 8/8 - 0s - loss: 0.0051 - ariel_challenge_metric_num: 0.0416
# Epoch 8/40
# 8/8 - 0s - loss: 0.0051 - ariel_challenge_metric_num: 0.0416
# Epoch 9/40
# 8/8 - 0s - loss: 0.0050 - ariel_challenge_metric_num: 0.0414
# Epoch 10/40
# 8/8 - 0s - loss: 0.0050 - ariel_challenge_metric_num: 0.0412
# Epoch 11/40
# 8/8 - 0s - loss: 0.0049 - ariel_challenge_metric_num: 0.0409
# Epoch 12/40
# 8/8 - 0s - loss: 0.0048 - ariel_challenge_metric_num: 0.0404
# Epoch 13/40
# 8/8 - 0s - loss: 0.0047 - ariel_challenge_metric_num: 0.0398
# Epoch 14/40
# 8/8 - 0s - loss: 0.0045 - ariel_challenge_metric_num: 0.0389
# Epoch 15/40
# 8/8 - 0s - loss: 0.0042 - ariel_challenge_metric_num: 0.0373
# Epoch 16/40
# 8/8 - 0s - loss: 0.0038 - ariel_challenge_metric_num: 0.0346
# Epoch 17/40
# 8/8 - 0s - loss: 0.0031 - ariel_challenge_metric_num: 0.0298
# Epoch 18/40
# 8/8 - 0s - loss: 0.0023 - ariel_challenge_metric_num: 0.0238
# Epoch 19/40
# 8/8 - 0s - loss: 0.0017 - ariel_challenge_metric_num: 0.0200
# Epoch 20/40
# 8/8 - 0s - loss: 0.0014 - ariel_challenge_metric_num: 0.0182
# Epoch 21/40
# 8/8 - 0s - loss: 0.0012 - ariel_challenge_metric_num: 0.0165
# Epoch 22/40
# 8/8 - 0s - loss: 0.0010 - ariel_challenge_metric_num: 0.0150
# Epoch 23/40
# 8/8 - 0s - loss: 9.6654e-04 - ariel_challenge_metric_num: 0.0141
# Epoch 24/40
# 8/8 - 0s - loss: 9.2386e-04 - ariel_challenge_metric_num: 0.0137
# Epoch 25/40
# 8/8 - 0s - loss: 9.0747e-04 - ariel_challenge_metric_num: 0.0135
# Epoch 26/40
# 8/8 - 0s - loss: 8.9407e-04 - ariel_challenge_metric_num: 0.0133
# Epoch 27/40
# 8/8 - 0s - loss: 8.8234e-04 - ariel_challenge_metric_num: 0.0131
# Epoch 28/40
# 8/8 - 0s - loss: 8.7362e-04 - ariel_challenge_metric_num: 0.0130
# Epoch 29/40
# 8/8 - 0s - loss: 8.6522e-04 - ariel_challenge_metric_num: 0.0128
# Epoch 30/40
# 8/8 - 0s - loss: 8.5767e-04 - ariel_challenge_metric_num: 0.0127
# Epoch 31/40
# 8/8 - 0s - loss: 8.4963e-04 - ariel_challenge_metric_num: 0.0126
# Epoch 32/40
# 8/8 - 0s - loss: 8.4195e-04 - ariel_challenge_metric_num: 0.0126
# Epoch 33/40
# 8/8 - 0s - loss: 8.3591e-04 - ariel_challenge_metric_num: 0.0124
# Epoch 34/40
# 8/8 - 0s - loss: 8.2844e-04 - ariel_challenge_metric_num: 0.0123
# Epoch 35/40
# 8/8 - 0s - loss: 8.2380e-04 - ariel_challenge_metric_num: 0.0122
# Epoch 36/40
# 8/8 - 0s - loss: 8.1728e-04 - ariel_challenge_metric_num: 0.0121
# Epoch 37/40
# 8/8 - 0s - loss: 8.1223e-04 - ariel_challenge_metric_num: 0.0120
# Epoch 38/40
# 8/8 - 0s - loss: 8.0678e-04 - ariel_challenge_metric_num: 0.0119
# Epoch 39/40
# 8/8 - 0s - loss: 8.0015e-04 - ariel_challenge_metric_num: 0.0118
# Epoch 40/40
# 8/8 - 0s - loss: 7.9471e-04 - ariel_challenge_metric_num: 0.0117
#
# Table 54 completed.

# %% [markdown]
# Though it seems like the training for these number of epochs (30) have not decrease to the minimum. So the number of epochs increase to 40. This could be further tuned if required. However, afraid that it might overfit, we will stop there and see how it does.

# %%
required_test_df.to_csv(storage_name, header=False, index=False, sep="\t")
